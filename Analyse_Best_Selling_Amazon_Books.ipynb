# %% [markdown]
# Importing pandas library and datasheet of amazon bestseller books in form of csv file

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/bestsellers.csv')

# %% [markdown]
# Exploring the data

# %%
# Get the first 5 rows of the spreadsheet
print(df.head())

# Get the shape of the spreadsheet
print(df.shape)

# Get the column names of the spreadsheet
print(df.columns)

# Get summary statistics for each column
print(df.describe())
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
# (550, 7)
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')
#        User Rating       Reviews       Price         Year
# ...

# %% [markdown]
# check for and remove any duplicate rows from dataset

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Renaming the columns for better understand

# %%
df.rename(columns={"Name": "Title", "Year": "Publication Year", "User Rating": "Rating"}, inplace=True)

# %% [markdown]
# Converting the price column to float data type to make it easier to work with

# %%
df["Price"] = df["Price"].astype(float)

# %% [markdown]
# Analyzing Author Popularity

# %%
author_counts = df['Author'].value_counts()
print(author_counts)
# Out:
# Author
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: count, Length: 248, dtype: int64

# %% [markdown]
# Average rating by Genre

# %%
avg_rating_by_genre = df.groupby("Genre")["Rating"].mean()
print(avg_rating_by_genre)
# Out:
# Genre
# Fiction        4.648333
# Non Fiction    4.595161
# Name: Rating, dtype: float64

# %% [markdown]
# Exporting the results to seperate csv files using to_csv method

# %%
# Export top selling authors to a CSV file
author_counts.head(10).to_csv("top_authors.csv")

# Export average rating by genre to a CSV file
avg_rating_by_genre.to_csv("avg_rating_by_genre.csv")

# %% [markdown]
# This was my project to analyze best selling  amazon books with pandas.

# %% [markdown]
# Thank You for going through my project.

# %% [markdown]
# ***SAYAN SOM***
